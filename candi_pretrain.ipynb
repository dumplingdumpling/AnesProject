# %%
import gentrl
import torch
import pickle
import pandas as pd
import matplotlib.pyplot as plt
import random
from utilities.candiconfig import CandiConfig

torch.cuda.set_device(0)

# %%
from moses.metrics import mol_passes_filters, QED, SA, logP
from moses.metrics.utils import get_n_rings, get_mol

def get_num_rings_6(mol):
    r = mol.GetRingInfo()
    return len([x for x in r.AtomRings() if len(x) > 6])


def penalized_logP(mol_or_smiles, masked=False, default=-5):
    mol = get_mol(mol_or_smiles)
    if mol is None:
        return default
    reward = logP(mol) - SA(mol) - get_num_rings_6(mol)
    if masked and not mol_passes_filters(mol):
        return default
    return reward

# %%
config = CandiConfig(smiles_format=2, topn_fp_features=5, mode='threshold', max_fp_features=2048, threshold=0.3, morgan_radius=2)
with open(config.FpsSOM_model, 'rb') as infile:
    fps_som = pickle.load(infile)

# %%
# LA_smiles, _ = fps_som.get_LA_zinc_data(multiplier=10)
# LA_list = [s+',train' for s in LA_smiles]

# zinc_list = []
# with open(config.zinc_file, 'r', encoding='utf-8') as f:
#     for line in f:
#         zinc_list.append(line.strip())

# zinc_list.remove('SMILES,SPLIT')
        
# mixed_list = zinc_list + LA_list

# random.shuffle(mixed_list)

# with open(config.mixed_dataset, 'w', encoding='utf-8') as f:
#     f.write('SMILES,SPLIT\n')
#     for s in mixed_list:
#         f.write(s+'\n')

# %%
# df = pd.read_csv(config.mixed_dataset)
# df = df[df['SPLIT'] == 'train']
# # df['plogP'] = df['SMILES'].apply(penalized_logP)
# df['reward'] = df['SMILES'].apply(fps_som.som_reward)
# df.to_csv(config.mixed_train_dataset, index=None)

# %%
md = gentrl.MolecularDataset(sources=[
    {'path':config.mixed_train_dataset,
     'smiles': 'SMILES',
     'prob': 1,
#      'plogP' : 'plogP',
     'reward' : 'reward',
    }], 
#    props=['plogP', 'reward'])
    props=['reward'])

from torch.utils.data import DataLoader
train_loader = DataLoader(md, batch_size=50, shuffle=True, num_workers=1, drop_last=True)

# %%
enc = gentrl.RNNEncoder(latent_size=50)
dec = gentrl.DilConvDecoder(latent_input_size=50)
model = gentrl.GENTRL(enc, dec, 50 * [('c', 20)], 1* [('c', 20)], beta=0.001)
model.cuda()
# Out:
# GENTRL(
#   (enc): RNNEncoder(
#     (embs): Embedding(28, 256)
#     (rnn): GRU(256, 256, num_layers=2)
#     (final_mlp): Sequential(
#       (0): Linear(in_features=256, out_features=256, bias=True)
#       (1): LeakyReLU(negative_slope=0.01)
#       (2): Linear(in_features=256, out_features=100, bias=True)
#     )
#   )
#   (dec): DilConvDecoder(
#     (latent_fc): Linear(in_features=50, out_features=128, bias=True)
#     (input_embeddings): Embedding(28, 128)
#     (logits_1x1_layer): Conv1d(128, 28, kernel_size=(1,), stride=(1,))
#     (parameters): ParameterList(
#         (0): Parameter containing: [torch.cuda.FloatTensor of size 28x128 (GPU 0)]
#         (1): Parameter containing: [torch.cuda.FloatTensor of size 28x128x1 (GPU 0)]
#         (2): Parameter containing: [torch.cuda.FloatTensor of size 28 (GPU 0)]
#         (3): Parameter containing: [torch.cuda.FloatTensor of size 128x50 (GPU 0)]
#         (4): Parameter containing: [torch.cuda.FloatTensor of size 128 (GPU 0)]
#         (5): Parameter containing: [torch.cuda.FloatTensor of size 128 (GPU 0)]
#         (6): Parameter containing: [torch.cuda.FloatTensor of size 128 (GPU 0)]
#         (7): Parameter containing: [torch.cuda.FloatTensor of size 128x128x1 (GPU 0)]
#         (8): Parameter containing: [torch.cuda.FloatTensor of size 128 (GPU 0)]
#         (9): Parameter containing: [torch.cuda.FloatTensor of size 128 (GPU 0)]
#         (10): Parameter containing: [torch.cuda.FloatTensor of size 128 (GPU 0)]
#         (11): Parameter containing: [torch.cuda.FloatTensor of size 128x128x2 (GPU 0)]
#         (12): Parameter containing: [torch.cuda.FloatTensor of size 128 (GPU 0)]
#         (13): Parameter containing: [torch.cuda.FloatTensor of size 128 (GPU 0)]
#         (14): Parameter containing: [torch.cuda.FloatTensor of size 128 (GPU 0)]
#         (15): Parameter containing: [torch.cuda.FloatTensor of size 128x128x1 (GPU 0)]
#         (16): Parameter containing: [torch.cuda.FloatTensor of size 128 (GPU 0)]
#         (17): Parameter containing: [torch.cuda.FloatTensor of size 128x128x1 (GPU 0)]
#         (18): Parameter containing: [torch.cuda.FloatTensor of size 128 (GPU 0)]
#         (19): Parameter containing: [torch.cuda.FloatTensor of size 128 (GPU 0)]
#         (20): Parameter containing: [torch.cuda.FloatTensor of size 128 (GPU 0)]
#         (21): Parameter containing: [torch.cuda.FloatTensor of size 128x128x1 (GPU 0)]
#         (22): Parameter containing: [torch.cuda.FloatTensor of size 128 (GPU 0)]
#         (23): Parameter containing: [torch.cuda.FloatTensor of size 128 (GPU 0)]
#         (24): Parameter containing: [torch.cuda.FloatTensor of size 128 (GPU 0)]
#         (25): Parameter containing: [torch.cuda.FloatTensor of size 128x128x2 (GPU 0)]
#         (26): Parameter containing: [torch.cuda.FloatTensor of size 128 (GPU 0)]
#         (27): Parameter containing: [torch.cuda.FloatTensor of size 128 (GPU 0)]
#         (28): Parameter containing: [torch.cuda.FloatTensor of size 128 (GPU 0)]
#         (29): Parameter containing: [torch.cuda.FloatTensor of size 128x128x1 (GPU 0)]
#         (30): Parameter containing: [torch.cuda.FloatTensor of size 128 (GPU 0)]
#         (31): Parameter containing: [torch.cuda.FloatTensor of size 128x128x1 (GPU 0)]
#         (32): Parameter containing: [torch.cuda.FloatTensor of size 128 (GPU 0)]
#         (33): Parameter containing: [torch.cuda.FloatTensor of size 128 (GPU 0)]
#         (34): Parameter containing: [torch.cuda.FloatTensor of size 128 (GPU 0)]
#         (35): Parameter containing: [torch.cuda.FloatTensor of size 128x128x1 (GPU 0)]
#         (36): Parameter containing: [torch.cuda.FloatTensor of size 128 (GPU 0)]
#         (37): Parameter containing: [torch.cuda.FloatTensor of size 128 (GPU 0)]
#         (38): Parameter containing: [torch.cuda.FloatTensor of size 128 (GPU 0)]
#         (39): Parameter containing: [torch.cuda.FloatTensor of size 128x128x2 (GPU 0)]
#         (40): Parameter containing: [torch.cuda.FloatTensor of size 128 (GPU 0)]
#         (41): Parameter containing: [torch.cuda.FloatTensor of size 128 (GPU 0)]
#         (42): Parameter containing: [torch.cuda.FloatTensor of size 128 (GPU 0)]
#         (43): Parameter containing: [torch.cuda.FloatTensor of size 128x128x1 (GPU 0)]
#         (44): Parameter containing: [torch.cuda.FloatTensor of size 128 (GPU 0)]
#         (45): Parameter containing: [torch.cuda.FloatTensor of size 128x128x1 (GPU 0)]
#         (46): Parameter containing: [torch.cuda.FloatTensor of size 128 (GPU 0)]
#         (47): Parameter containing: [torch.cuda.FloatTensor of size 128 (GPU 0)]
#         (48): Parameter containing: [torch.cuda.FloatTensor of size 128 (GPU 0)]
#         (49): Parameter containing: [torch.cuda.FloatTensor of size 128x128x1 (GPU 0)]
#         (50): Parameter containing: [torch.cuda.FloatTensor of size 128 (GPU 0)]
#         (51): Parameter containing: [torch.cuda.FloatTensor of size 128 (GPU 0)]
#         (52): Parameter containing: [torch.cuda.FloatTensor of size 128 (GPU 0)]
#         (53): Parameter containing: [torch.cuda.FloatTensor of size 128x128x2 (GPU 0)]
#         (54): Parameter containing: [torch.cuda.FloatTensor of size 128 (GPU 0)]
#         (55): Parameter containing: [torch.cuda.FloatTensor of size 128 (GPU 0)]
#         (56): Parameter containing: [torch.cuda.FloatTensor of size 128 (GPU 0)]
#         (57): Parameter containing: [torch.cuda.FloatTensor of size 128x128x1 (GPU 0)]
#         (58): Parameter containing: [torch.cuda.FloatTensor of size 128 (GPU 0)]
#         (59): Parameter containing: [torch.cuda.FloatTensor of size 128x128x1 (GPU 0)]
#         (60): Parameter containing: [torch.cuda.FloatTensor of size 128 (GPU 0)]
#         (61): Parameter containing: [torch.cuda.FloatTensor of size 128 (GPU 0)]
#         (62): Parameter containing: [torch.cuda.FloatTensor of size 128 (GPU 0)]
#         (63): Parameter containing: [torch.cuda.FloatTensor of size 128x128x1 (GPU 0)]
#         (64): Parameter containing: [torch.cuda.FloatTensor of size 128 (GPU 0)]
#         (65): Parameter containing: [torch.cuda.FloatTensor of size 128 (GPU 0)]
#         (66): Parameter containing: [torch.cuda.FloatTensor of size 128 (GPU 0)]
#         (67): Parameter containing: [torch.cuda.FloatTensor of size 128x128x2 (GPU 0)]
#         (68): Parameter containing: [torch.cuda.FloatTensor of size 128 (GPU 0)]
#         (69): Parameter containing: [torch.cuda.FloatTensor of size 128 (GPU 0)]
#         (70): Parameter containing: [torch.cuda.FloatTensor of size 128 (GPU 0)]
#         (71): Parameter containing: [torch.cuda.FloatTensor of size 128x128x1 (GPU 0)]
#         (72): Parameter containing: [torch.cuda.FloatTensor of size 128 (GPU 0)]
#         (73): Parameter containing: [torch.cuda.FloatTensor of size 128x128x1 (GPU 0)]
#         (74): Parameter containing: [torch.cuda.FloatTensor of size 128 (GPU 0)]
#         (75): Parameter containing: [torch.cuda.FloatTensor of size 128 (GPU 0)]
#         (76): Parameter containing: [torch.cuda.FloatTensor of size 128 (GPU 0)]
#         (77): Parameter containing: [torch.cuda.FloatTensor of size 128x128x1 (GPU 0)]
#         (78): Parameter containing: [torch.cuda.FloatTensor of size 128 (GPU 0)]
#         (79): Parameter containing: [torch.cuda.FloatTensor of size 128 (GPU 0)]
#         (80): Parameter containing: [torch.cuda.FloatTensor of size 128 (GPU 0)]
#         (81): Parameter containing: [torch.cuda.FloatTensor of size 128x128x2 (GPU 0)]
#         (82): Parameter containing: [torch.cuda.FloatTensor of size 128 (GPU 0)]
#         (83): Parameter containing: [torch.cuda.FloatTensor of size 128 (GPU 0)]
#         (84): Parameter containing: [torch.cuda.FloatTensor of size 128 (GPU 0)]
#         (85): Parameter containing: [torch.cuda.FloatTensor of size 128x128x1 (GPU 0)]
#         (86): Parameter containing: [torch.cuda.FloatTensor of size 128 (GPU 0)]
#         (87): Parameter containing: [torch.cuda.FloatTensor of size 128x128x1 (GPU 0)]
#         (88): Parameter containing: [torch.cuda.FloatTensor of size 128 (GPU 0)]
#         (89): Parameter containing: [torch.cuda.FloatTensor of size 128 (GPU 0)]
#         (90): Parameter containing: [torch.cuda.FloatTensor of size 128 (GPU 0)]
#         (91): Parameter containing: [torch.cuda.FloatTensor of size 128x128x1 (GPU 0)]
#         (92): Parameter containing: [torch.cuda.FloatTensor of size 128 (GPU 0)]
#         (93): Parameter containing: [torch.cuda.FloatTensor of size 128 (GPU 0)]
#         (94): Parameter containing: [torch.cuda.FloatTensor of size 128 (GPU 0)]
#         (95): Parameter containing: [torch.cuda.FloatTensor of size 128x128x2 (GPU 0)]
#         (96): Parameter containing: [torch.cuda.FloatTensor of size 128 (GPU 0)]
#         (97): Parameter containing: [torch.cuda.FloatTensor of size 128 (GPU 0)]
#         (98): Parameter containing: [torch.cuda.FloatTensor of size 128 (GPU 0)]
#         (99): Parameter containing: [torch.cuda.FloatTensor of size 128x128x1 (GPU 0)]
#         (100): Parameter containing: [torch.cuda.FloatTensor of size 128 (GPU 0)]
#         (101): Parameter containing: [torch.cuda.FloatTensor of size 128x128x1 (GPU 0)]
#         (102): Parameter containing: [torch.cuda.FloatTensor of size 128 (GPU 0)]
#     )
#   )
#   (lp): LP(
#     (parameters): ParameterList(
#         (0): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (1): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (2): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (3): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (4): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (5): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (6): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (7): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (8): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (9): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (10): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (11): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (12): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (13): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (14): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (15): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (16): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (17): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (18): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (19): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (20): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (21): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (22): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (23): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (24): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (25): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (26): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (27): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (28): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (29): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (30): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (31): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (32): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (33): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (34): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (35): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (36): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (37): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (38): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (39): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (40): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (41): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (42): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (43): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (44): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (45): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (46): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (47): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (48): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (49): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (50): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (51): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (52): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (53): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (54): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (55): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (56): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (57): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (58): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (59): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (60): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (61): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (62): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (63): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (64): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (65): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (66): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (67): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (68): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (69): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (70): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (71): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (72): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (73): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (74): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (75): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (76): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (77): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (78): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (79): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (80): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (81): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (82): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (83): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (84): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (85): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (86): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (87): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (88): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (89): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (90): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (91): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (92): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (93): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (94): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (95): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (96): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (97): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (98): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (99): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (100): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (101): Parameter containing: [torch.cuda.FloatTensor of size 20 (GPU 0)]
#         (102): Parameter containing: [torch.cuda.FloatTensor of size 20x40x40 (GPU 0)]
#         (103): Parameter containing: [torch.cuda.FloatTensor of size 20x40x40 (GPU 0)]
#         (104): Parameter containing: [torch.cuda.FloatTensor of size 20x40x40 (GPU 0)]
#         (105): Parameter containing: [torch.cuda.FloatTensor of size 20x40x40 (GPU 0)]
#         (106): Parameter containing: [torch.cuda.FloatTensor of size 20x40x40 (GPU 0)]
#         (107): Parameter containing: [torch.cuda.FloatTensor of size 20x40x40 (GPU 0)]
#         (108): Parameter containing: [torch.cuda.FloatTensor of size 20x40x40 (GPU 0)]
#         (109): Parameter containing: [torch.cuda.FloatTensor of size 20x40x40 (GPU 0)]
#         (110): Parameter containing: [torch.cuda.FloatTensor of size 20x40x40 (GPU 0)]
#         (111): Parameter containing: [torch.cuda.FloatTensor of size 20x40x40 (GPU 0)]
#         (112): Parameter containing: [torch.cuda.FloatTensor of size 20x40x40 (GPU 0)]
#         (113): Parameter containing: [torch.cuda.FloatTensor of size 20x40x40 (GPU 0)]
#         (114): Parameter containing: [torch.cuda.FloatTensor of size 20x40x40 (GPU 0)]
#         (115): Parameter containing: [torch.cuda.FloatTensor of size 20x40x40 (GPU 0)]
#         (116): Parameter containing: [torch.cuda.FloatTensor of size 20x40x40 (GPU 0)]
#         (117): Parameter containing: [torch.cuda.FloatTensor of size 20x40x40 (GPU 0)]
#         (118): Parameter containing: [torch.cuda.FloatTensor of size 20x40x40 (GPU 0)]
#         (119): Parameter containing: [torch.cuda.FloatTensor of size 20x40x40 (GPU 0)]
#         (120): Parameter containing: [torch.cuda.FloatTensor of size 20x40x40 (GPU 0)]
#         (121): Parameter containing: [torch.cuda.FloatTensor of size 20x40x40 (GPU 0)]
#         (122): Parameter containing: [torch.cuda.FloatTensor of size 20x40x40 (GPU 0)]
#         (123): Parameter containing: [torch.cuda.FloatTensor of size 20x40x40 (GPU 0)]
#         (124): Parameter containing: [torch.cuda.FloatTensor of size 20x40x40 (GPU 0)]
#         (125): Parameter containing: [torch.cuda.FloatTensor of size 20x40x40 (GPU 0)]
#         (126): Parameter containing: [torch.cuda.FloatTensor of size 20x40x40 (GPU 0)]
#         (127): Parameter containing: [torch.cuda.FloatTensor of size 20x40x40 (GPU 0)]
#         (128): Parameter containing: [torch.cuda.FloatTensor of size 20x40x40 (GPU 0)]
#         (129): Parameter containing: [torch.cuda.FloatTensor of size 20x40x40 (GPU 0)]
#         (130): Parameter containing: [torch.cuda.FloatTensor of size 20x40x40 (GPU 0)]
#         (131): Parameter containing: [torch.cuda.FloatTensor of size 20x40x40 (GPU 0)]
#         (132): Parameter containing: [torch.cuda.FloatTensor of size 20x40x40 (GPU 0)]
#         (133): Parameter containing: [torch.cuda.FloatTensor of size 20x40x40 (GPU 0)]
#         (134): Parameter containing: [torch.cuda.FloatTensor of size 20x40x40 (GPU 0)]
#         (135): Parameter containing: [torch.cuda.FloatTensor of size 20x40x40 (GPU 0)]
#         (136): Parameter containing: [torch.cuda.FloatTensor of size 20x40x40 (GPU 0)]
#         (137): Parameter containing: [torch.cuda.FloatTensor of size 20x40x40 (GPU 0)]
#         (138): Parameter containing: [torch.cuda.FloatTensor of size 20x40x40 (GPU 0)]
#         (139): Parameter containing: [torch.cuda.FloatTensor of size 20x40x40 (GPU 0)]
#         (140): Parameter containing: [torch.cuda.FloatTensor of size 20x40x40 (GPU 0)]
#         (141): Parameter containing: [torch.cuda.FloatTensor of size 20x40x40 (GPU 0)]
#         (142): Parameter containing: [torch.cuda.FloatTensor of size 20x40x40 (GPU 0)]
#         (143): Parameter containing: [torch.cuda.FloatTensor of size 20x40x40 (GPU 0)]
#         (144): Parameter containing: [torch.cuda.FloatTensor of size 20x40x40 (GPU 0)]
#         (145): Parameter containing: [torch.cuda.FloatTensor of size 20x40x40 (GPU 0)]
#         (146): Parameter containing: [torch.cuda.FloatTensor of size 20x40x40 (GPU 0)]
#         (147): Parameter containing: [torch.cuda.FloatTensor of size 20x40x40 (GPU 0)]
#         (148): Parameter containing: [torch.cuda.FloatTensor of size 20x40x40 (GPU 0)]
#         (149): Parameter containing: [torch.cuda.FloatTensor of size 20x40x40 (GPU 0)]
#         (150): Parameter containing: [torch.cuda.FloatTensor of size 20x40x40 (GPU 0)]
#         (151): Parameter containing: [torch.cuda.FloatTensor of size 20x40x40 (GPU 0)]
#         (152): Parameter containing: [torch.cuda.FloatTensor of size 20x40x40 (GPU 0)]
#     )
#   )
# )

# %%
model.train_as_vaelp(train_loader, lr=1e-4)
# Out:
# Epoch 0 :
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-56fa529d1191> in <module>
# ----> 1 model.train_as_vaelp(train_loader, lr=1e-4)
#
# ~/LocalAnesthetics/gentrl/gentrl.py in train_as_vaelp(self, train_loader, num_epochs, verbose_step, lr)
#     190                 optimizer.zero_grad()
#     191                 loss = -elbo
# --> 192                 loss.backward()
#     193                 optimizer.step()
#     194
#
# ~/anaconda3/envs/my-rdkit-env/lib/python3.7/site-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     361                 create_graph=create_graph,
#     362                 inputs=inputs)
# --> 363         torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#     364
#     365     def register_hook(self, hook):
#
# ~/anaconda3/envs/my-rdkit-env/lib/python3.7/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     173     Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     174         tensors, grad_tensors_, retain_graph, create_graph, inputs,
# --> 175         allow_unreachable=True, accumulate_grad=True)  # Calls into the C++ engine to run the backward pass
#     176
#     177 def grad(
#
# KeyboardInterrupt:
